# %%
import pandas as pd

# %%
file = 'data/Galileo Baird Data CST (Updated).xlsx'
Galileo_Baird = pd.ExcelFile(file)

# %%
Galileo_Baird.sheet_names
# Out:
# [u'2017-18', u'2016-17', u'2015-16', u'2014-15', u'2013-14']

# %%
Galileo_Baird_17_18 = Galileo_Baird.parse('2017-18')
Galileo_Baird_16_17 = Galileo_Baird.parse('2016-17')
Galileo_Baird_15_16 = Galileo_Baird.parse('2015-16')
Galileo_Baird_14_15 = Galileo_Baird.parse('2014-15')
Galileo_Baird_13_14 = Galileo_Baird.parse('2013-14')

# %%
Galileo_Baird_13_14
# Out:
#                          Name   Pre Score  Pre %  Post Score  Post %  \
# 0                   Arreola, J       14.0  0.304        16.0   0.348
# 1                    Campos, A        NaN    NaN         NaN     NaN
# 2                      Cano, G       11.0  0.239        14.0   0.304
# 3                      Cole, S        4.0  0.087        10.0   0.217
# 4                    Garcia, A        NaN    NaN         NaN     NaN
# 5                    Garcio, J        NaN    NaN         NaN     NaN
# 6                     Gibbs, B       10.0  0.217        13.0   0.283
# 7                     Green, K       12.0  0.261         9.0   0.196
# 8                   Gonzaga, J       12.0  0.261        12.0   0.261
# 9                    Hughey, M       14.0  0.304        13.0   0.283
# 10                   Little, I        NaN    NaN         NaN     NaN
# 11                    Lopez, D       11.0  0.239        17.0   0.370
# 12                 Mitchell, T       14.0  0.304        14.0   0.304
# ...

# %%
old = pd.DataFrame()
old['a'] = [1,2,3]
old['b'] = [12,13,14]

# %%
new = old.drop('a', axis=1)

# %%
new
# Out:
#     b
# 0  12
# 1  13
# 2  14
